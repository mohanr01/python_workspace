# %% [markdown]
# # python tutorial
# ## fundamentals
# - data types

# %%
4*20
# Out:
# 80

# %%
5+4
# Out:
# 9

# %%
45/8
# Out:
# 5.625

# %%
# to get the type of data

# %%
type(45/8)
# Out:
# float

# %%
# string 
"vivek"
# Out:
# 'vivek'

# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=5
print(a+b)
# Out:
# 15

# %%
print("welcome {}".format('mohan'))
# Out:
# welcome mohan

# %%
first_word = 'mohan'

# %%
print("hi hello {}, how are you".format(first_word))
# Out:
# hi hello mohan, how are you

# %%
len(first_word)
# Out:
# 5

# %% [markdown]
# ## Boolean and List

# %%
type(True)
type(False)
# Out:
# bool

# %%
"mohan".endswith("n")
# Out:
# True

# %%
"list".upper()
# Out:
# 'LIST'

# %%
a="list".upper()
print(a)
# Out:
# LIST

# %%
mystr="anish12"

# %%
print(mystr.isdigit())
print(mystr.istitle())
print(mystr.isalpha())
print(mystr.isalnum())
# Out:
# False
# False
# False
# True

# %% [markdown]
# ## Boolean and Logical Operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
(mystr!='null' and mystr=='anish12')
# Out:
# True

# %% [markdown]
# ## List

# %%
mylist=[]
type(mylist)
# Out:
# list

# %%
mylist=['var1','var2',100,200,'var3']
len(mylist)
# Out:
# 5

# %%
mylist.append('var4')

# %%
mylist
# Out:
# ['var1', 'var2', 100, 200, 'var3', 'var4']

# %%
##index in list

# %%
print(mylist[5])
mylist[1:4]
# Out:
# var4
# ['var2', 100, 200]

# %%
mylist.append(['var5','var6'])
print(mylist)
# Out:
# ['var1', 'var2', 100, 200, 'var3', 'var4', ['var5', 'var6']]

# %%
##insert

# %%
mylist=[]
mylist
# Out:
# []

# %%
mylist=[1,2,3,4,5,6]

# %%
mylist.insert(2,0)
mylist.index(0)
# Out:
# 2

# %%
mylist.sort()
mylist
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
mylist.extend([7,8])
mylist
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
mylist.reverse()
mylist
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1, 0]

# %%
mylist.pop(0)
mylist
# Out:
# [7, 6, 5, 4, 3, 2, 1, 0]

# %%
mylist = [11,12,13,14,15]
mylist.remove(11)

# %%
mylist
# Out:
# [12, 13, 14, 15]

# %%
mylist.index(15,0,4)
# Out:
# 3

# %% [markdown]
# ## set and dictionary

# %%
set_var={"ram","mohan","ram"}
print(set_var)
# Out:
# {'mohan', 'ram'}

# %%
set1={"ram","sundar"}
set2={"rajesh","sundar"}
set1=set1.union(set2)
print(set1)
# Out:
# {'rajesh', 'sundar', 'ram'}

# %%
print(set1,'::',set2)
set1.intersection(set2)
# Out:
# {'rajesh', 'sundar', 'ram'} :: {'rajesh', 'sundar'}
# {'rajesh', 'sundar'}

# %%
print(set1,set2)
# Out:
# {'rajesh', 'sundar', 'ram'} {'rajesh', 'sundar'}

# %%
set1.add("sanjay")
print(set1)
# Out:
# {'rajesh', 'sundar', 'sanjay', 'ram'}

# %%
#indexing not applicable in set
set1['sanjay']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 #indexing
# ----> 2 set1['sanjay']
#
# TypeError: 'set' object is not subscriptable

# %%
set1.difference_update(set2)

# %%
print(set1)
# Out:
# {'sanjay', 'ram'}

# %%
for x in set1:
    print(x)
# Out:
# sanjay
# ram

# %%
# dictornary is unordered and key value pairs item

# %%
dict1={"car1":"maruti","car2":"BMW","car3":"mini"}
type(dict1)
# Out:
# dict

# %%
# indexing in dictionary
dict1['car1']
# Out:
# 'maruti'

# %%
## tuple is cannot able to change

# %%
my_tuple=('Raju','kumar')

# %%
my_tuple.index('kumar')
# Out:
# 1

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple.count("kumar")
# Out:
# 1

# %%
## pandas section
pandas is open source, easy to use data structure and data analysis tool
point to cover:
1. data frames
2. data series
3. different operations in pandas
4. using pandas we can read and write the data from file
5. read json data format

# %%
import pandas as pd
import numpy as np

# %%
data1 = np.random.randint(100,size=(2, 4))
data1
# Out:
# array([[24, 33, 57, 99],
#        [41, 68, 89, 21]])

# %%
df = pd.DataFrame(data1,index=["row1","row2"],columns=["col1","col2","col3","col4"])
df
# Out:
#       col1  col2  col3  col4
# row1    24    33    57    99
# row2    41    68    89    21

# %%
# converting to excel
df.to_csv('out.csv', index=False)  # doctest: +SKIP

# %%
# Index accessing element
df.loc['row1']
# Out:
# col1    24
# col2    33
# col3    57
# col4    99
# Name: row1, dtype: int32

# %%
type(df.loc['row1'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[:,0:2]
# Out:
#       col1  col2
# row1    24    33
# row2    41    68

# %%
type(df.iloc[:,0:2])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       col1  col2  col3  col4
# row1    24    33    57    99
# row2    41    68    89    21

# %%
df.isnull().sum()
# Out:
# col1    0
# col2    0
# col3    0
# col4    0
# dtype: int64

# %%
df['col2']
# Out:
# row1    33
# row2    68
# Name: col2, dtype: int32

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# read data from csv file

# %%
df1 = pd.read_csv("C:\\Users\\Mohan\\python_workspace\\fundamental\\resources\\customer_sample.csv")

# %%
df1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df1.to_pickle('df1_csv')

# %%
df1.head(3)
# Out:
#    Index      Customer Id First Name Last Name          Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano      Vega-Gentry
# 2      3  6F94879bDAfE5a6        Roy     Berry    Murillo-Perry
#
#                 City              Country       Phone 1              Phone 2  \
# 0       East Leonard                Chile  229.077.5154     397.884.0519x718
# 1  East Jimmychester             Djibouti    5153435776     686-620-1820x944
# 2      Isabelborough  Antigua and Barbuda         -1199  (496)978-3969x58947
#
#                       Email Subscription Date                     Website
# 0  zunigavanessa@smith.info        24-08-2020  http://www.stephenson.com/
# 1           vmata@colon.com        23-04-2021       http://www.hobbs.com/
# 2       beckycarr@hogan.com        25-03-2020    http://www.lawrence.com/

# %%
df1.info(show_counts=3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
df1.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df1['Customer Id'].head(5)
# Out:
# 0    DD37Cf93aecA6Dc
# 1    1Ef7b82A4CAAD10
# 2    6F94879bDAfE5a6
# 3    5Cef8BFA16c5e3c
# 4    053d585Ab6b3159
# Name: Customer Id, dtype: object

# %%
df1['Customer Id'].value_counts()
# Out:
# Customer Id
# DD37Cf93aecA6Dc    1
# FCBdfCEAe20A8Dc    1
# A3F76Be153Df4a3    1
# F560f2d3cDFb618    1
# Ef859092FbEcC07    1
#                   ..
# 64DCcDFaB9DFd4e    1
# EDA69ca7a6e96a2    1
# 3B5dAAFA41AFa22    1
# b92EBfdF8a3f0E6    1
# 2354a0E336A91A1    1
# Name: count, Length: 100, dtype: int64

# %%
from io import StringIO, BytesIO

# %%
df2 = ('col1,col2,col3\n'
       'x,y,z\n'
       'a,b,c\n'
       '1,2,3\n')

# %%
StringIO()

# %%
cs = pd.read_csv(StringIO(df2))

# %%
cs
# Out:
#   col1 col2 col3
# 0    x    y    z
# 1    a    b    c
# 2    1    2    3

# %%
## using pandas read the json data

# %%
jsondata = '''{"menu": {  
  "id": "file",  

  "value": "File",  
  "popup": {  
    "menuitem": [  
      {"value": "New", "onclick": "CreateDoc()"},  
      {"value": "Open", "onclick": "OpenDoc()"},  
      {"value": "Save", "onclick": "SaveDoc()"}  
    ]  
  }  
}}'''

# %%
jsonframe = pd.read_json(StringIO(jsondata))
jsonframe
# Out:
#                                                     menu
# id                                                  file
# value                                               File
# popup  {'menuitem': [{'value': 'New', 'onclick': 'Cre...

# %%
content = jsonframe.to_string()
content
# Out:
# "                                                                                                                                                   menu\nid                                                                                                                                                 file\nvalue                                                                                                                                              File\npopup  {'menuitem': [{'value': 'New', 'onclick': 'CreateDoc()'}, {'value': 'Open', 'onclick': 'OpenDoc()'}, {'value': 'Save', 'onclick': 'SaveDoc()'}]}"

# %%
content = jsonframe.to_json()
content
# Out:
# '{"menu":{"id":"file","value":"File","popup":{"menuitem":[{"value":"New","onclick":"CreateDoc()"},{"value":"Open","onclick":"OpenDoc()"},{"value":"Save","onclick":"SaveDoc()"}]}}}'

# %%
type(content)
# Out:
# str

# %%
jsonframe.to_json(orient="records")
# Out:
# '[{"menu":"file"},{"menu":"File"},{"menu":{"menuitem":[{"value":"New","onclick":"CreateDoc()"},{"value":"Open","onclick":"OpenDoc()"},{"value":"Save","onclick":"SaveDoc()"}]}}]'

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://en.wikipedia.org/wiki/States_and_union_territories_of_India'
pd.read_html(url,match="Tamil Nadu",header=0)
# Out:
# [               States and union territories of India  \
#  0  Andhra Pradesh Arunachal Pradesh Assam Bihar C...
#  1                                           Category
#  2                                           Location
#  3                                             Number
#  4                                        Populations
#  5                                              Areas
#  6                                         Government
#  7                                       Subdivisions
#
#               States and union territories of India.1
#  0  Andhra Pradesh Arunachal Pradesh Assam Bihar C...
#  1                                   Federated states
#  2                                  Republic of India
#  3                     28 States 8  Union territories
#  4  States: Sikkim – 610,577 (lowest) Uttar Prades...
#  5  States: Goa – 3,702 km2 (1,429 sq mi) (smalles...
#  6  State Governments Union Government (union terr...
# ...

# %%
## read pickling

# %%
df1.to_pickle('df1_csv')

# %%
pd.read_pickle('C:\\Users\\Mohan\\python_workspace\\fundamental\\df1_csv')
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...
